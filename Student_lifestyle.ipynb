# %%
#importing pandas
import pandas as pd

# %% [markdown]
# ##Reading Data

# %%
#Load the dataset
df=pd.read_csv("/content/student_lifestyle_dataset.csv",encoding='latin1')

#Make a copy of the dataset
df1=df.copy()

# %% [markdown]
# ##Exploring data

# %%
#Checking the info of the dataset
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Student_ID                       2000 non-null   int64
#  1   Study_Hours_Per_Day              2000 non-null   float64
#  2   Extracurricular_Hours_Per_Day    2000 non-null   float64
#  3   Sleep_Hours_Per_Day              2000 non-null   float64
#  4   Social_Hours_Per_Day             2000 non-null   float64
#  5   Physical_Activity_Hours_Per_Day  2000 non-null   float64
#  6   GPA                              2000 non-null   float64
#  7   Stress_Level                     2000 non-null   object
# dtypes: float64(6), int64(1), object(1)
# memory usage: 125.1+ KB

# %%
#Checking the number of rows and columns
df1.shape
# Out:
# (2000, 8)

# %%
#Checking the first 5 rows of the dataset
df1.head(5)
# Out:
#    Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# 0           1                  6.9                            3.8
# 1           2                  5.3                            3.5
# 2           3                  5.1                            3.9
# 3           4                  6.5                            2.1
# 4           5                  8.1                            0.6
#
#    Sleep_Hours_Per_Day  Social_Hours_Per_Day  Physical_Activity_Hours_Per_Day  \
# 0                  8.7                   2.8                              1.8
# 1                  8.0                   4.2                              3.0
# 2                  9.2                   1.2                              4.6
# 3                  7.2                   1.7                              6.5
# 4                  6.5                   2.2                              6.6
#
#     GPA Stress_Level
# 0  2.99     Moderate
# 1  2.75          Low
# 2  2.67          Low
# 3  2.88     Moderate
# 4  3.51         High

# %%
#checking the last 5 rows of the dataset
df1.tail(5)
# Out:
#       Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# 1995        1996                  6.5                            0.2
# 1996        1997                  6.3                            2.8
# 1997        1998                  6.2                            0.0
# 1998        1999                  8.1                            0.7
# 1999        2000                  9.0                            1.7
#
#       Sleep_Hours_Per_Day  Social_Hours_Per_Day  \
# 1995                  7.4                   2.1
# 1996                  8.8                   1.5
# 1997                  6.2                   0.8
# 1998                  7.6                   3.5
# 1999                  7.3                   3.1
#
#       Physical_Activity_Hours_Per_Day   GPA Stress_Level
# 1995                              7.8  3.32     Moderate
# 1996                              4.6  2.65     Moderate
# 1997                             10.8  3.14     Moderate
# 1998                              4.1  3.04         High
# 1999                              2.9  3.58         High

# %%
#Checking for unique values
df1.nunique()
# Out:
# Student_ID                         2000
# Study_Hours_Per_Day                  51
# Extracurricular_Hours_Per_Day        41
# Sleep_Hours_Per_Day                  51
# Social_Hours_Per_Day                 61
# Physical_Activity_Hours_Per_Day     118
# GPA                                 158
# Stress_Level                          3
# dtype: int64

# %%
#Statistical summary of the dataset
df1.describe().T
# Out:
#                                   count        mean         std   min     25%  \
# Student_ID                       2000.0  1000.50000  577.494589  1.00  500.75
# Study_Hours_Per_Day              2000.0     7.47580    1.423888  5.00    6.30
# Extracurricular_Hours_Per_Day    2000.0     1.99010    1.155855  0.00    1.00
# Sleep_Hours_Per_Day              2000.0     7.50125    1.460949  5.00    6.20
# Social_Hours_Per_Day             2000.0     2.70455    1.688514  0.00    1.20
# Physical_Activity_Hours_Per_Day  2000.0     4.32830    2.514110  0.00    2.40
# GPA                              2000.0     3.11596    0.298674  2.24    2.90
#
#                                      50%      75%     max
# Student_ID                       1000.50  1500.25  2000.0
# Study_Hours_Per_Day                 7.40     8.70    10.0
# Extracurricular_Hours_Per_Day       2.00     3.00     4.0
# Sleep_Hours_Per_Day                 7.50     8.80    10.0
# Social_Hours_Per_Day                2.60     4.10     6.0
# Physical_Activity_Hours_Per_Day     4.10     6.10    13.0
# GPA                                 3.11     3.33     4.0

# %% [markdown]
# ##Handling missing data

# %%
#Checking for missing values
df1.isnull().sum()
# Out:
# Student_ID                         0
# Study_Hours_Per_Day                0
# Extracurricular_Hours_Per_Day      0
# Sleep_Hours_Per_Day                0
# Social_Hours_Per_Day               0
# Physical_Activity_Hours_Per_Day    0
# GPA                                0
# Stress_Level                       0
# dtype: int64

# %%
#checking for duplicates
df1.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##Grouping and Aggregation

# %%
#Aggregation
df1.agg(['sum', 'min', 'max'])
# Out:
#      Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# sum     2001000              14951.6                         3980.2
# min           1                  5.0                            0.0
# max        2000                 10.0                            4.0
#
#      Sleep_Hours_Per_Day  Social_Hours_Per_Day  \
# sum              15002.5                5409.1
# min                  5.0                   0.0
# max                 10.0                   6.0
#
#      Physical_Activity_Hours_Per_Day      GPA  \
# sum                           8656.6  6231.92
# min                              0.0     2.24
# max                             13.0     4.00
#
#                                           Stress_Level
# sum  ModerateLowLowModerateHighModerateHighHighLowM...
# min                                               High
# max                                           Moderate

# %%
#Grouping
df1.groupby(["Stress_Level","GPA"]).sum()
# Out:
#                    Student_ID  Study_Hours_Per_Day  \
# Stress_Level GPA
# High         2.31         383                  5.3
#              2.38         159                  6.1
#              2.42        1444                  5.7
#              2.45         863                  5.9
#              2.48         743                  5.2
# ...                       ...                  ...
# Moderate     3.50         525                  7.9
#              3.51        1635                  7.3
#              3.54        2467                 14.4
#              3.56        1056                  7.6
#              3.75        1899                  7.9
#
#                    Extracurricular_Hours_Per_Day  Sleep_Hours_Per_Day  \
# Stress_Level GPA
# High         2.31                            2.0                  5.2
#              2.38                            1.8                  5.7
#              2.42                            3.0                  5.0
#              2.45                            1.9                  5.5
#              2.48                            1.7                  5.8
# ...                                          ...                  ...
# Moderate     3.50                            0.6                  9.1
#              3.51                            1.9                  9.4
#              3.54                            2.3                 15.1
#              3.56                            0.1                  8.2
#              3.75                            2.3                  7.4
#
#                    Social_Hours_Per_Day  Physical_Activity_Hours_Per_Day
# Stress_Level GPA
# High         2.31                   0.4                             11.1
#              2.38                   1.1                              9.3
#              2.42                   1.0                              9.3
#              2.45                   3.8                              6.9
#              2.48                   5.3                              6.0
# ...                                 ...                              ...
# Moderate     3.50                   3.8                              2.6
#              3.51                   4.1                              1.3
#              3.54                   7.1                              9.1
#              3.56                   0.5                              7.6
#              3.75                   3.3                              3.1
#
# [334 rows x 6 columns]

# %% [markdown]
# ##Sorting and indexing

# %%
#Sorting based on column labels
df1.sort_index(axis=1)
# Out:
#       Extracurricular_Hours_Per_Day   GPA  Physical_Activity_Hours_Per_Day  \
# 0                               3.8  2.99                              1.8
# 1                               3.5  2.75                              3.0
# 2                               3.9  2.67                              4.6
# 3                               2.1  2.88                              6.5
# 4                               0.6  3.51                              6.6
# ...                             ...   ...                              ...
# 1995                            0.2  3.32                              7.8
# 1996                            2.8  2.65                              4.6
# 1997                            0.0  3.14                             10.8
# 1998                            0.7  3.04                              4.1
# 1999                            1.7  3.58                              2.9
#
#       Sleep_Hours_Per_Day  Social_Hours_Per_Day Stress_Level  Student_ID  \
# 0                     8.7                   2.8     Moderate           1
# 1                     8.0                   4.2          Low           2
# 2                     9.2                   1.2          Low           3
# 3                     7.2                   1.7     Moderate           4
# 4                     6.5                   2.2         High           5
# ...                   ...                   ...          ...         ...
# 1995                  7.4                   2.1     Moderate        1996
# 1996                  8.8                   1.5     Moderate        1997
# 1997                  6.2                   0.8     Moderate        1998
# 1998                  7.6                   3.5         High        1999
# 1999                  7.3                   3.1         High        2000
#
#       Study_Hours_Per_Day
# 0                     6.9
# 1                     5.3
# 2                     5.1
# 3                     6.5
# 4                     8.1
# ...                   ...
# 1995                  6.5
# 1996                  6.3
# 1997                  6.2
# 1998                  8.1
# 1999                  9.0
#
# [2000 rows x 8 columns]

# %% [markdown]
# ##Dropping a column

# %%
df1.drop('Sleep_Hours_Per_Day',axis=1)
# Out:
#       Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# 0              1                  6.9                            3.8
# 1              2                  5.3                            3.5
# 2              3                  5.1                            3.9
# 3              4                  6.5                            2.1
# 4              5                  8.1                            0.6
# ...          ...                  ...                            ...
# 1995        1996                  6.5                            0.2
# 1996        1997                  6.3                            2.8
# 1997        1998                  6.2                            0.0
# 1998        1999                  8.1                            0.7
# 1999        2000                  9.0                            1.7
#
#       Social_Hours_Per_Day  Physical_Activity_Hours_Per_Day   GPA Stress_Level
# 0                      2.8                              1.8  2.99     Moderate
# 1                      4.2                              3.0  2.75          Low
# 2                      1.2                              4.6  2.67          Low
# 3                      1.7                              6.5  2.88     Moderate
# 4                      2.2                              6.6  3.51         High
# ...                    ...                              ...   ...          ...
# 1995                   2.1                              7.8  3.32     Moderate
# 1996                   1.5                              4.6  2.65     Moderate
# 1997                   0.8                             10.8  3.14     Moderate
# 1998                   3.5                              4.1  3.04         High
# 1999                   3.1                              2.9  3.58         High
#
# [2000 rows x 7 columns]
